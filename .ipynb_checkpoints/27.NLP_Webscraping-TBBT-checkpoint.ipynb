# %% [markdown]
# ## Ejercicio NLP & WebScraping
#
# 1. Hacer web scraping para obtener todos los diálogos de cada capítulo de la serie.
# 2. Unificar los textos de cada capítulo en uno solo.
# 3. Separar los diálogos por personaje (Sheldon, Leonard, Penny, Raj, Howard, Amy).
# 4. Tokenizar cada dialogo por personaje.
# 5. Eliminar stopwords y signos de puntuación (. , : ; ¡ ¿ ? …) de las listas con tokens.
# 6. Encontrar la riqueza léxica de cada personaje.
# 7. Encontrar las 5 palabras más utilizadas por cada personaje.
# 8. Encontrar palabras similares para la palabra más utilizada de cada personaje.
# 9. Encontrar hápax de cada personaje.
# 10. Mostrar en una gráfica las 20 palabras que más se utilizan.

# %% [markdown]
# En primer lugar definimos todas las librerías que vamos a utilizar.

# %%
import requests
from bs4 import BeautifulSoup

import os
import re
import csv

import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.text import Text
from nltk import FreqDist

import string

from collections import Counter
import pandas as pd
import matplotlib.pyplot as plt
import time

# %% [markdown]
# ### 1. Extraemos los textos

# %%
#Identificamos la carpeta donde se guardarán los archivos de texto de los diálogos
carpeta_destino = "Ejercicio_TBBT"

#Definimos una función para extraer y guardar el contenido de los capítulos
def scrapping(url, capitulo):
    response = requests.get(url)
    soup = BeautifulSoup(response.text, "html.parser")
    entrytext = soup.find("div", class_="entrytext")
    
    if entrytext:
        parrafos = entrytext.find_all("p")
        dialogo = "\n".join([p.text for p in parrafos])
        
        archivo = f"Capitulo_{capitulo}.txt"
        ruta_archivo = os.path.join(carpeta_destino, archivo)
        
        with open(ruta_archivo, "w", encoding="utf-8") as file: #Guardamos el diálogo en un archivo de texto
            file.write(dialogo)
        print(f"Capítulo {capitulo} guardado en {archivo}")
    else:
        print(f"No se pudo encontrar el contenido en {url}")
# Out:
# Capítulo 1 guardado en Capitulo_1.txt
# Capítulo 2 guardado en Capitulo_2.txt
# Capítulo 3 guardado en Capitulo_3.txt
# Capítulo 4 guardado en Capitulo_4.txt
# Capítulo 5 guardado en Capitulo_5.txt
# Capítulo 6 guardado en Capitulo_6.txt
# Capítulo 7 guardado en Capitulo_7.txt
# Capítulo 8 guardado en Capitulo_8.txt
# Capítulo 9 guardado en Capitulo_9.txt
# Capítulo 10 guardado en Capitulo_10.txt
# Capítulo 11 guardado en Capitulo_11.txt
# Capítulo 12 guardado en Capitulo_12.txt
# Capítulo 13 guardado en Capitulo_13.txt
# Capítulo 14 guardado en Capitulo_14.txt
# Capítulo 15 guardado en Capitulo_15.txt
# Capítulo 16 guardado en Capitulo_16.txt
# Capítulo 17 guardado en Capitulo_17.txt
# Capítulo 18 guardado en Capitulo_18.txt
# Capítulo 19 guardado en Capitulo_19.txt
# Capítulo 20 guardado en Capitulo_20.txt
# Capítulo 21 guardado en Capitulo_21.txt
# Capítulo 22 guardado en Capitulo_22.txt
# Capítulo 23 guardado en Capitulo_23.txt
# Capítulo 24 guardado en Capitulo_24.txt
# Capítulo 25 guardado en Capitulo_25.txt
# Capítulo 26 guardado en Capitulo_26.txt
# Capítulo 27 guardado en Capitulo_27.txt
# Capítulo 28 guardado en Capitulo_28.txt
# Capítulo 29 guardado en Capitulo_29.txt
# Capítulo 30 guardado en Capitulo_30.txt
# Capítulo 31 guardado en Capitulo_31.txt
# Capítulo 32 guardado en Capitulo_32.txt
# Capítulo 33 guardado en Capitulo_33.txt
# Capítulo 34 guardado en Capitulo_34.txt
# Capítulo 35 guardado en Capitulo_35.txt
# Capítulo 36 guardado en Capitulo_36.txt
# Capítulo 37 guardado en Capitulo_37.txt
# Capítulo 38 guardado en Capitulo_38.txt
# Capítulo 39 guardado en Capitulo_39.txt
# Capítulo 40 guardado en Capitulo_40.txt
# Capítulo 41 guardado en Capitulo_41.txt
# Capítulo 42 guardado en Capitulo_42.txt
# Capítulo 43 guardado en Capitulo_43.txt
# Capítulo 44 guardado en Capitulo_44.txt
# Capítulo 45 guardado en Capitulo_45.txt
# Capítulo 46 guardado en Capitulo_46.txt
# Capítulo 47 guardado en Capitulo_47.txt
# Capítulo 48 guardado en Capitulo_48.txt
# Capítulo 49 guardado en Capitulo_49.txt
# Capítulo 50 guardado en Capitulo_50.txt
# Capítulo 51 guardado en Capitulo_51.txt
# Capítulo 52 guardado en Capitulo_52.txt
# Capítulo 53 guardado en Capitulo_53.txt
# Capítulo 54 guardado en Capitulo_54.txt
# Capítulo 55 guardado en Capitulo_55.txt
# Capítulo 56 guardado en Capitulo_56.txt
# Capítulo 57 guardado en Capitulo_57.txt
# Capítulo 58 guardado en Capitulo_58.txt
# Capítulo 59 guardado en Capitulo_59.txt
# Capítulo 60 guardado en Capitulo_60.txt
# Capítulo 61 guardado en Capitulo_61.txt
# Capítulo 62 guardado en Capitulo_62.txt
# Capítulo 63 guardado en Capitulo_63.txt
# Capítulo 64 guardado en Capitulo_64.txt
# Capítulo 65 guardado en Capitulo_65.txt
# Capítulo 66 guardado en Capitulo_66.txt
# Capítulo 67 guardado en Capitulo_67.txt
# Capítulo 68 guardado en Capitulo_68.txt
# Capítulo 69 guardado en Capitulo_69.txt
# Capítulo 70 guardado en Capitulo_70.txt
# Capítulo 71 guardado en Capitulo_71.txt
# Capítulo 72 guardado en Capitulo_72.txt
# Capítulo 73 guardado en Capitulo_73.txt
# Capítulo 74 guardado en Capitulo_74.txt
# Capítulo 75 guardado en Capitulo_75.txt
# Capítulo 76 guardado en Capitulo_76.txt
# Capítulo 77 guardado en Capitulo_77.txt
# Capítulo 78 guardado en Capitulo_78.txt
# Capítulo 79 guardado en Capitulo_79.txt
# Capítulo 80 guardado en Capitulo_80.txt
# Capítulo 81 guardado en Capitulo_81.txt
# Capítulo 82 guardado en Capitulo_82.txt
# Capítulo 83 guardado en Capitulo_83.txt
# Capítulo 84 guardado en Capitulo_84.txt
# Capítulo 85 guardado en Capitulo_85.txt
# Capítulo 86 guardado en Capitulo_86.txt
# Capítulo 87 guardado en Capitulo_87.txt
# Capítulo 88 guardado en Capitulo_88.txt
# Capítulo 89 guardado en Capitulo_89.txt
# Capítulo 90 guardado en Capitulo_90.txt
# Capítulo 91 guardado en Capitulo_91.txt
# Capítulo 92 guardado en Capitulo_92.txt
# Capítulo 93 guardado en Capitulo_93.txt
# Capítulo 94 guardado en Capitulo_94.txt
# Capítulo 95 guardado en Capitulo_95.txt
# Capítulo 96 guardado en Capitulo_96.txt
# Capítulo 97 guardado en Capitulo_97.txt
# Capítulo 98 guardado en Capitulo_98.txt
# Capítulo 99 guardado en Capitulo_99.txt
# Capítulo 100 guardado en Capitulo_100.txt
# Capítulo 101 guardado en Capitulo_101.txt
# Capítulo 102 guardado en Capitulo_102.txt
# Capítulo 103 guardado en Capitulo_103.txt
# Capítulo 104 guardado en Capitulo_104.txt
# Capítulo 105 guardado en Capitulo_105.txt
# Capítulo 106 guardado en Capitulo_106.txt
# Capítulo 107 guardado en Capitulo_107.txt
# Capítulo 108 guardado en Capitulo_108.txt
# Capítulo 109 guardado en Capitulo_109.txt
# Capítulo 110 guardado en Capitulo_110.txt
# Capítulo 111 guardado en Capitulo_111.txt
# Capítulo 112 guardado en Capitulo_112.txt
# Capítulo 113 guardado en Capitulo_113.txt
# Capítulo 114 guardado en Capitulo_114.txt
# Capítulo 115 guardado en Capitulo_115.txt
# Capítulo 116 guardado en Capitulo_116.txt
# Capítulo 117 guardado en Capitulo_117.txt
# Capítulo 118 guardado en Capitulo_118.txt
# Capítulo 119 guardado en Capitulo_119.txt
# Capítulo 120 guardado en Capitulo_120.txt
# Capítulo 121 guardado en Capitulo_121.txt
# Capítulo 122 guardado en Capitulo_122.txt
# Capítulo 123 guardado en Capitulo_123.txt
# Capítulo 124 guardado en Capitulo_124.txt
# Capítulo 125 guardado en Capitulo_125.txt
# Capítulo 126 guardado en Capitulo_126.txt
# Capítulo 127 guardado en Capitulo_127.txt
# Capítulo 128 guardado en Capitulo_128.txt
# Capítulo 129 guardado en Capitulo_129.txt
# Capítulo 130 guardado en Capitulo_130.txt
# Capítulo 131 guardado en Capitulo_131.txt
# Capítulo 132 guardado en Capitulo_132.txt
# Capítulo 133 guardado en Capitulo_133.txt
# Capítulo 134 guardado en Capitulo_134.txt
# Capítulo 135 guardado en Capitulo_135.txt
# Capítulo 136 guardado en Capitulo_136.txt
# Capítulo 137 guardado en Capitulo_137.txt
# Capítulo 138 guardado en Capitulo_138.txt
# Capítulo 139 guardado en Capitulo_139.txt
# Capítulo 140 guardado en Capitulo_140.txt
# Capítulo 141 guardado en Capitulo_141.txt
# Capítulo 142 guardado en Capitulo_142.txt
# Capítulo 143 guardado en Capitulo_143.txt
# Capítulo 144 guardado en Capitulo_144.txt
# Capítulo 145 guardado en Capitulo_145.txt
# Capítulo 146 guardado en Capitulo_146.txt
# Capítulo 147 guardado en Capitulo_147.txt
# Capítulo 148 guardado en Capitulo_148.txt
# Capítulo 149 guardado en Capitulo_149.txt
# Capítulo 150 guardado en Capitulo_150.txt
# Capítulo 151 guardado en Capitulo_151.txt
# Capítulo 152 guardado en Capitulo_152.txt
# Capítulo 153 guardado en Capitulo_153.txt
# Capítulo 154 guardado en Capitulo_154.txt
# Capítulo 155 guardado en Capitulo_155.txt
# Capítulo 156 guardado en Capitulo_156.txt
# Capítulo 157 guardado en Capitulo_157.txt
# Capítulo 158 guardado en Capitulo_158.txt
# Capítulo 159 guardado en Capitulo_159.txt
# Capítulo 160 guardado en Capitulo_160.txt
# Capítulo 161 guardado en Capitulo_161.txt
# Capítulo 162 guardado en Capitulo_162.txt
# Capítulo 163 guardado en Capitulo_163.txt
# Capítulo 164 guardado en Capitulo_164.txt
# Capítulo 165 guardado en Capitulo_165.txt
# Capítulo 166 guardado en Capitulo_166.txt
# Capítulo 167 guardado en Capitulo_167.txt
# Capítulo 168 guardado en Capitulo_168.txt
# Capítulo 169 guardado en Capitulo_169.txt
# Capítulo 170 guardado en Capitulo_170.txt
# Capítulo 171 guardado en Capitulo_171.txt
# Capítulo 172 guardado en Capitulo_172.txt
# Capítulo 173 guardado en Capitulo_173.txt
# Capítulo 174 guardado en Capitulo_174.txt
# Capítulo 175 guardado en Capitulo_175.txt
# Capítulo 176 guardado en Capitulo_176.txt
# Capítulo 177 guardado en Capitulo_177.txt
# Capítulo 178 guardado en Capitulo_178.txt
# Capítulo 179 guardado en Capitulo_179.txt
# Capítulo 180 guardado en Capitulo_180.txt
# Capítulo 181 guardado en Capitulo_181.txt
# Capítulo 182 guardado en Capitulo_182.txt
# Capítulo 183 guardado en Capitulo_183.txt
# Capítulo 184 guardado en Capitulo_184.txt
# Capítulo 185 guardado en Capitulo_185.txt
# Capítulo 186 guardado en Capitulo_186.txt
# Capítulo 187 guardado en Capitulo_187.txt
# Capítulo 188 guardado en Capitulo_188.txt
# Capítulo 189 guardado en Capitulo_189.txt
# Capítulo 190 guardado en Capitulo_190.txt
# Capítulo 191 guardado en Capitulo_191.txt
# Capítulo 192 guardado en Capitulo_192.txt
# Capítulo 193 guardado en Capitulo_193.txt
# Capítulo 194 guardado en Capitulo_194.txt
# Capítulo 195 guardado en Capitulo_195.txt
# Capítulo 196 guardado en Capitulo_196.txt
# Capítulo 197 guardado en Capitulo_197.txt
# Capítulo 198 guardado en Capitulo_198.txt
# Capítulo 199 guardado en Capitulo_199.txt
# Capítulo 200 guardado en Capitulo_200.txt
# Capítulo 201 guardado en Capitulo_201.txt
# Capítulo 202 guardado en Capitulo_202.txt
# Capítulo 203 guardado en Capitulo_203.txt
# Capítulo 204 guardado en Capitulo_204.txt
# Capítulo 205 guardado en Capitulo_205.txt
# Capítulo 206 guardado en Capitulo_206.txt
# Capítulo 207 guardado en Capitulo_207.txt
# Capítulo 208 guardado en Capitulo_208.txt
# Capítulo 209 guardado en Capitulo_209.txt
# Capítulo 210 guardado en Capitulo_210.txt
# Capítulo 211 guardado en Capitulo_211.txt
# Capítulo 212 guardado en Capitulo_212.txt
# Capítulo 213 guardado en Capitulo_213.txt
# Capítulo 214 guardado en Capitulo_214.txt
# Capítulo 215 guardado en Capitulo_215.txt
# Capítulo 216 guardado en Capitulo_216.txt
# Capítulo 217 guardado en Capitulo_217.txt
# Capítulo 218 guardado en Capitulo_218.txt
# Capítulo 219 guardado en Capitulo_219.txt
# Capítulo 220 guardado en Capitulo_220.txt
# Capítulo 221 guardado en Capitulo_221.txt
# Capítulo 222 guardado en Capitulo_222.txt
# Capítulo 223 guardado en Capitulo_223.txt
# Capítulo 224 guardado en Capitulo_224.txt
# Capítulo 225 guardado en Capitulo_225.txt
# Capítulo 226 guardado en Capitulo_226.txt
# Capítulo 227 guardado en Capitulo_227.txt
# Capítulo 228 guardado en Capitulo_228.txt
# Capítulo 229 guardado en Capitulo_229.txt
# Capítulo 230 guardado en Capitulo_230.txt
# Capítulo 231 guardado en Capitulo_231.txt

# %%
#URL de la página sobre la que trabajar
url = "https://bigbangtrans.wordpress.com/series-1-episode-1-pilot-episode/"

#Realizamos la solicitud a la URL y comprobamos si fue exitosa
response = requests.get(url)

if response.status_code == 200:
    soup = BeautifulSoup(response.text, "html.parser")
    
    #Previamente hemos analizado la página y ubicado dónde están los elementos que buscamos, como el div con id "sidebar"
    sidebar = soup.find(id="sidebar")
    
    #Localizamos las etiquetas <li> dentro de "sidebar"
    etiquetas_li = sidebar.find_all("li")
    
    #Establecemos una lista para almacenar las URLs
    urls = []
    
    #Recorremos las etiquetas <li> y extraemos las URLs
    for etiqueta_li in etiquetas_li:
        #Ignoramos la etiqueta con el nombre "About", puesto que no tiene nada de interés.
        if "About" not in etiqueta_li.text:
            # Obtener la URL del atributo "href"
            url = etiqueta_li.find("a")["href"]
            urls.append(url)
    
    #Creamos un dataframe de pandas con las URLs
    df = pd.DataFrame(urls, columns=["URLs"])
    
    #Lo guardamos en un archivo CSV
    df.to_csv("Ejercicio_TBBT/urls_TBBT.csv", index=False)
    
    print("URLs extraídas y guardadas en 'urls_TBBT.csv'.")
else:
    print("No se pudo acceder a la página web.")

# %%
df = pd.read_csv("Ejercicio_TBBT/urls_TBBT.csv")

#Identificamos la carpeta donde se guardarán los archivos de texto de los diálogos
carpeta_destino = "Ejercicio_TBBT"

# %%
lista = df.values.tolist()

lista_plana = []

for sublist in lista:
    lista_plana.extend(sublist)

# %%
urls = lista_plana

# %%
#Iteramos a través de las URLs para extraer los diálogos
for i, url in enumerate(urls, start=1):
    scrapping(url, i)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 #Iteramos a través de las URLs para extraer los diálogos
#       2 for i, url in enumerate(urls, start=1):
# ----> 3     scrapping(url, i)
#
# NameError: name 'scrapping' is not defined

# %% [markdown]
# ### 2. Unificar los textos

# %%
textos = []

for i in range(1, 232):
    archivo = f"Ejercicio_TBBT/Capitulo_{i}.txt"
    try:
        with open(archivo, "r", encoding="utf-8") as file:
            texto_capitulo = file.read()
            textos.append(texto_capitulo)
    except FileNotFoundError:
        print(f"El archivo {archivo} no se encontró.")

texto_unico = "\n\n".join(textos)

archivo_unico = f"Ejercicio_TBBT/Capitulos_totales.txt"
with open(archivo_unico, "w", encoding="utf-8") as file:
    file.write(texto_unico)

print(f"Los textos se han unido en {archivo_unico}")
# Out:
# Los textos se han unido en Ejercicio_TBBT/Capitulos_totales.txt

# %%
archivo_unico = "Ejercicio_TBBT/Capitulos_totales.txt"

with open(archivo_unico, "r", encoding="utf-8") as file:
    texto_unificado = file.read()

texto_sin_parentesis = re.sub(r'\([^)]*\)', '', texto_unificado)

# %% [markdown]
# ### 3. Separar los diálogos

# %%
#Dividimos los diálogos por líneas
lineas = texto_sin_parentesis.split('\n')

#Inicializamos un diccionario para almacenar los diálogos por cada personaje
dialogos_por_personaje = {}

#Recorremos las líneas y separamos los diálogos por personaje. Para ello indicamos que ":" es el indicativo en cada línea de quién es el personaje
personaje_actual = None
for linea in lineas:
    if ":" in linea:
        partes = linea.split(":")
        personaje_actual = partes[0].strip()
        dialogo = ":".join(partes[1:]).strip()
        if personaje_actual in dialogos_por_personaje:
            dialogos_por_personaje[personaje_actual].append(dialogo)
        else:
            dialogos_por_personaje[personaje_actual] = [dialogo]
    elif personaje_actual is not None:
        dialogos_por_personaje[personaje_actual][-1] += f"\n{linea.strip()}"

# %%
personajes_permitidos = ["Sheldon", "Leonard", "Penny", "Raj", "Howard", "Amy"]

#Creamos un nuevo diccionario con los personajes permitidos exclusivamente
dialogos_filtrados = {key: value for key, value in dialogos_por_personaje.items() if key in personajes_permitidos}

# %% [markdown]
# ### 4. Tokenizar los diálogos

# %%
#El símbolo "’" en los textos nos va a dar problemas, así que lo reemplazamos por "'"
for personaje, dialogos in dialogos_filtrados.items():
    dialogos_filtrados[personaje] = [dialogo.replace("’", "'") for dialogo in dialogos]

#Creamos un nuevo diccionario para los diálogos tokenizados
dialogos_tokenizados = {}

#Tokenizamos los diálogos de cada personaje
for personaje, dialogos in dialogos_filtrados.items():
    dialogos_tokenizados[personaje] = [word_tokenize(dialogo, language='english') for dialogo in dialogos]

# %% [markdown]
# ### 5. Eliminar stepwords y signos

# %%
stopwords = nltk.corpus.stopwords.words("english")

#Lista de signos de puntuación que deseamos eliminar
punctuation = [".", ",", ":", ";", "!", "?", "…"]

#Definimos una función para limpiar los tokens de un diálogo
def limpiar_tokens(tokens):
    tokens_limpios = [token for token in tokens if token.lower() not in stopwords and token not in punctuation]
    return tokens_limpios

# %%
#"Limpiamos" los tokens de todos los diálogos en un nuevo diccionario
dialogos_tokenizados_limpios = {}
for personaje, tokens_dialogo in dialogos_tokenizados.items():
    dialogos_limpios = [limpiar_tokens(tokens) for tokens in tokens_dialogo]
    dialogos_tokenizados_limpios[personaje] = dialogos_limpios

#Como hemos visto que las palabras con apóstrofes no se han quitado, creamos una función para eliminarlas
def eliminar_palabras_con_apostrofe(dialogos_tokenizados):
    dialogos_sap = {}
    for personaje, dialogos in dialogos_tokenizados.items():
        dialogos_sap[personaje] = [
            [palabra for palabra in dialogo if "'" not in palabra] # Filtramos palabras sin apóstrofes
            for dialogo in dialogos
        ]
    return dialogos_sap

# Aplicamos la función
dialogos_limpios = eliminar_palabras_con_apostrofe(dialogos_tokenizados_limpios)

# %% [markdown]
# ### 6. Encontrar riqueza léxica

# %%
#Creamos un diccionario para almacenar la riqueza léxica de cada personaje
riqueza_lexica = {}

#Calculamos la riqueza léxica para cada personaje
for personaje, dialogo in dialogos_limpios.items():
    #Obtenemos una lista de todas las palabras en los diálogos del personaje
    palabras_totales = [palabra for frase in dialogo for palabra in frase]
    #Calculamos el número de palabras únicas
    palabras_unicas = set(palabras_totales)
    # Calculamos la riqueza léxica dividiendo el número de palabras únicas entre el número total de palabras
    riqueza = len(palabras_unicas) / len(palabras_totales)
    riqueza_lexica[personaje] = riqueza

#Mostramos la riqueza léxica de cada personaje
for personaje, riqueza in riqueza_lexica.items():
    print(f"Riqueza léxica de {personaje}: {riqueza:.2f}")
# Out:
# Riqueza léxica de Sheldon: 0.19
# Riqueza léxica de Leonard: 0.18
# Riqueza léxica de Penny: 0.16
# Riqueza léxica de Howard: 0.23
# Riqueza léxica de Raj: 0.24
# Riqueza léxica de Amy: 0.28

# %% [markdown]
# ### 7. Encontrar 3 palabras más utilizadas

# %%
#Creamos un diccionario para almacenar las 3 palabras más utilizadas por cada personaje
palabras_mas_utilizadas = {}

#Buscamos las 3 palabras más utilizadas
for personaje, dialogo in dialogos_limpios.items():
    # Obtener una lista plana de todas las palabras en los diálogos del personaje
    palabras_totales = [palabra for frase in dialogo for palabra in frase]
    #Contamos la frecuencia de cada palabra
    frecuencia_palabras = Counter(palabras_totales)
    #Obtenemos las 3 más utilizadas
    palabras_top = frecuencia_palabras.most_common(3)
    palabras_mas_utilizadas[personaje] = palabras_top

#Mostramos las 3 más utilizadas
for personaje, palabras_top in palabras_mas_utilizadas.items():
    print(f"Las 3 palabras más utilizadas de {personaje}:")
    for palabra, frecuencia in palabras_top:
        print(f"{palabra}: {frecuencia} veces")
    print()
# Out:
# Las 3 palabras más utilizadas de Sheldon:
# Oh: 1057 veces
# know: 823 veces
# Leonard: 759 veces
#
# Las 3 palabras más utilizadas de Leonard:
# know: 641 veces
# Oh: 595 veces
# Sheldon: 590 veces
#
# Las 3 palabras más utilizadas de Penny:
# Oh: 907 veces
# know: 719 veces
# Okay: 616 veces
#
# Las 3 palabras más utilizadas de Howard:
# know: 388 veces
# Oh: 348 veces
# like: 301 veces
#
# Las 3 palabras más utilizadas de Raj:
# Oh: 362 veces
# like: 349 veces
# know: 324 veces
#
# Las 3 palabras más utilizadas de Amy:
# Sheldon: 361 veces
# know: 244 veces
# like: 188 veces

# %% [markdown]
# ### 8. Encontrar similares a la más utilizada

# %%
#Creamos un diccionario para almacenar la palabra más utilizada por cada personaje
palabra_mas_utilizada = {}

#Localizamos la palabra más utilizada por cada personaje
for personaje, dialogos in dialogos_limpios.items():
    #Unimos todos los diálogos de un personaje en una lista única de palabras
    todas_las_palabras = [palabra for dialogo in dialogos for palabra in dialogo]  
    #Calculamos su frecuencia
    frecuencia_palabras = FreqDist(todas_las_palabras) 
    # Encontramos la más común
    palabra_mas_comun = frecuencia_palabras.most_common(1)[0][0]
    #La almacenamos en el diccionario
    palabra_mas_utilizada[personaje] = palabra_mas_comun

#Y la mostramos
for personaje, palabra in palabra_mas_utilizada.items():
    print(f"La palabra más utilizada por {personaje} es: {palabra}")
# Out:
# La palabra más utilizada por Sheldon es: Oh
# La palabra más utilizada por Leonard es: know
# La palabra más utilizada por Penny es: Oh
# La palabra más utilizada por Howard es: know
# La palabra más utilizada por Raj es: Oh
# La palabra más utilizada por Amy es: Sheldon

# %%
#Convertimos el diccionario en una lista de tuplas
lista_palabras_mas_utilizadas = [(personaje, palabra) for personaje, palabra in palabra_mas_utilizada.items()]

#Creamos un diccionario nuevo para almacenar las similares
palabras_similares = {}

#Buscamos las "similares" para cada personaje (sabiendo que no son similares en cuanto a significado sino en contexto)
for personaje, palabra_mas_utilizada in lista_palabras_mas_utilizadas:
    #Convertimos los diálogos de cada personaje en una lista
    palabras_personaje = [palabra for dialogo in dialogos_limpios[personaje] for palabra in dialogo]   
    #Convertimos la lista en un objeto Text para así poder utilizar la función
    texto_personaje = nltk.text.ContextIndex(palabras_personaje)
    #Encontramos las similares utilizando la función similar_words()
    similares = texto_personaje.similar_words(palabra_mas_utilizada)    
    #Las almacenamos en el diccionario
    palabras_similares[personaje] = similares

#Las mostramos para cada personaje
for personaje, similares in palabras_similares.items():
    print(similares)
# Out:
# ['dear', 'oh', 'Leonard', 'Well', 'Penny', 'good', 'know', 'well', 'Uh', 'right', 'please', 'Amy', 'said', 'even', 'happy', 'never', 'think', 'everyone', 'remember', 'Hold']
# ['uh', 'go', 'yeah', 'come', 'well', 'good', 'Yeah', 'Sheldon', 'think', 'got', 'Penny', 'talk', 'would', 'hi', 'kind', 'right', 'need', 'say', 'Howard', 'still']
# ['God', 'okay', 'Okay', 'Yeah', 'right', 'Sheldon', 'really', 'know', 'yeah', 'come', 'fine', 'want', 'guys', 'Well', 'Leonard', 'sorry', 'good', 'got', 'going', 'um']
# ['like', 'yeah', 'Yeah', 'disgusted', 'talk', 'shops', 'ca', 'romantic', 'goblins', 'ring', 'ancestors', 'priority', 'Must', 'might', 'sound', 'say', 'hey', 'made', 'guys', 'bigger']
# ['Okay', 'uh', 'um', 'God', 'great', 'join', 'Well', 'look', 'messages', 'evening', 'tell', 'plot', 'guys', 'help', 'team', 'prom', 'Leonard', 'love', 'adventure', 'coming']
# ['Okay', 'really', 'pretty', 'Fine', 'think', 'bestie', 'one', 'Oh', 'get', 'mean', 'Let', 'right', 'ca', 'going', 'understanding', 'Sorry', 'Hi', 'bringing', 'Would', 'found']

# %% [markdown]
# ### 9. Encontrar hápax de cada personaje

# %%
#Creamos un diccionario nuevo para almacenar los hápax de cada personaje, que son palabras que solo utiliza una vez
hapax_por_personaje = {}

#Buscamos los hápax de cada personaje
for personaje, dialogos in dialogos_limpios.items():    
    #Buscamos los hápax
    hapax = [palabra for palabra, frecuencia in frecuencia_palabras.items() if frecuencia == 1] 
    #Los almacenamos en el diccionario
    hapax_por_personaje[personaje] = hapax

#Los mostramos por cada personaje
for personaje, hapax in hapax_por_personaje.items():
    print(f"Hapax para {personaje}:")
    print(hapax)
# Out:
# Hapax para Sheldon:
# ['unfamiliar', 'aversion', 'soiled', 'hosiery', 'concept', 'deity', 'baffled', 'attendance', 'Noted', 'Tepid', 'Neurobiologist', 'indicates…', 'Dandruff', 'scalp', 'flattered', 'factoid', 'silence', 'occasional', 'Foreman', 'Grill', 'seals', 'flavour', 'fat', 'Remarkable', 'Cultural', 'perceptions', 'subjective', 'slut', 'volunteering', 'electronically', 'centres', '128', 'rhinoceroses', 'domesticated', 'pets', 'wins', 'Second', 'Defend', 'Correct', 'Tuned', 'bayonets', 'postulate', 'alternate', 'differs', 'pose', 'giant', 'builds', 'dams', 'overlord', 'low-lying', 'city', 'Copenhagen', 'flooded', 'Thousands', 'Devastated', 'Danes', 'invent', 'namesake', 'pastry', 'kinder', 'suited', 'hiding', 'feminine', 'supplies', 'Subject', 'entropy', 'decay', 'eventual', 'establishment', 'efficiently', 'festival', 'humdrum', 'chitchat', 'master', 'degree', 'subtle', 'compared', 'real-world', 'outright', 'Babinski', 'Dirac', 'defecates', 'Clarke-Maxwell', 'mapping', 'neurological', 'substrates', 'subserve', 'global', 'processing', 'required', 'inquiry', 'ipso', 'prior', 'ordo', 'cognoscendi', 'extension', 'deriving', 'unified', 'subsume', 'conclusions', 'appear', 'impasse', 'Seconded', 'Excellent', 'Touche', 'stipulate', '80', '%', 'difficulties', 'caused', 'Sixty-five', 'cast', 'oddly', 'titillating', 'cats', 'epitome', 'indifference', 'observation', 'standpoint', 'psychological', 'state', 'actual', 'pheromone-based', 'stink', 'desperation', 'places', 'taverns', 'tavern', 'Juice', 'Cornucopia', 'Certainly', 'misunderstanding', 'occurred', 'screwed', 'satisfied', 'Precisely', 'cultural', 'construct', 'adds', 'clarification', 'allows', 'boy-slash-friend-slash-girl-slash-friend', 'status', 'suffocating', 'hunger', 'stirring', 'newest', 'gain', 'acceptance', 'arbitrarily', 'siding', 'arrive', 'winding', 'seats', 'assuming', 'Girls', 'entail', 'synchronized', 'unusually', 'firm', 'cervix', 'titled', 'graduate', 'fungus', 'grows', 'improperly', 'sterilized', 'implements', 'bond', 'BFF', 'makeovers', 'initiate', 'phony', 'spirited', 'fights', 'frilly', 'nighties', 'disappointing', 'tonsils', 'shared', 'Vietnamese', 'Pillow', 'grasp', 'familiarizing', 'fairly', 'straightforward', 'heat', 'prion', 'circumference', 'areolas', 'Absolon', 'hath', 'kist', 'hir', 'Nicholas', 'scalded', 'towte', 'tale', 'doon', 'al', 'rowte', 'dared', 'Miller', 'Tale', 'dirtiest', 'hidden', 'drawers', '14th', 'worn', 'socks', 'Hint', 'ought', 'claim', 'pair-bonded', 'inordinate', 'ex', 'post', 'option', 'terminate', 'react', 'unavailable', 'realized', 'scored', 'Clearly', 'guests', 'harmless', 'lesbianism', 'iconic', 'bending', 'flummoxed', 'satisfactory', 'flushed', 'clammy', 'addition', 'involuntarily', 'sudden-onset', 'Tourette', 'syndrome', 'foot-long', 'Quiznos', 'examination', 'donate', 'slice', 'Canadian', 'experienced', 'distressing', 'vital', 'signs', 'Elevated', 'localized', 'vascular', 'throbbing', 'Ears', 'carbonated', 'Ask', 'alien', 'parasite', 'shows', 'Cortisol', 'menopause', 'aroused', 'logically', 'stomach', 'arousal', 'Religion', 'philosophies', 'fiction', 'concern', 'motivated', 'reject', 'suppressing', 'specimens', 'pursuit', 'pure', 'founded', 'logic', '130', 'raging', 'estrogen', 'gluteus', 'maximus', 'Shakespeare', 'metaphorical', 'beast', 'backs', 'blank', 'ape-like', 'adopt', 'Vulcan', 'Kolinar', 'Institute', 'Interdisciplinary', 'Studies', 'interactions', 'blog', 'all-expense-paid', 'spa', 'four-star', 'resort', 'Sur', 'establish', 'boundaries', 'valid', 'principle', 'upgraded', 'discussed', 'jeopardize', 'bunk', 'constipated', 'ideal', 'radioactive', 'lanthanoid', 'Remind', 'subscribe', 'Freudian', 'penis', 'envy', 'convenience', 'deny', 'comparison', 'plumbing', 'Word', 'though', 'prone', 'terrors', 'kicking', 'screaming', 'panic', 'stroke', 'penises', 'weigh', '120', 'miles', 'per', 'arrow', 'quiver', 'troubling', 'isolating', 'stored', 'destroying', 'laser', 'improving', 'socialization', 'thus', 'effectively', 'essence', 'teaching', 'perfo ...
# Hapax para Leonard:
# ['unfamiliar', 'aversion', 'soiled', 'hosiery', 'concept', 'deity', 'baffled', 'attendance', 'Noted', 'Tepid', 'Neurobiologist', 'indicates…', 'Dandruff', 'scalp', 'flattered', 'factoid', 'silence', 'occasional', 'Foreman', 'Grill', 'seals', 'flavour', 'fat', 'Remarkable', 'Cultural', 'perceptions', 'subjective', 'slut', 'volunteering', 'electronically', 'centres', '128', 'rhinoceroses', 'domesticated', 'pets', 'wins', 'Second', 'Defend', 'Correct', 'Tuned', 'bayonets', 'postulate', 'alternate', 'differs', 'pose', 'giant', 'builds', 'dams', 'overlord', 'low-lying', 'city', 'Copenhagen', 'flooded', 'Thousands', 'Devastated', 'Danes', 'invent', 'namesake', 'pastry', 'kinder', 'suited', 'hiding', 'feminine', 'supplies', 'Subject', 'entropy', 'decay', 'eventual', 'establishment', 'efficiently', 'festival', 'humdrum', 'chitchat', 'master', 'degree', 'subtle', 'compared', 'real-world', 'outright', 'Babinski', 'Dirac', 'defecates', 'Clarke-Maxwell', 'mapping', 'neurological', 'substrates', 'subserve', 'global', 'processing', 'required', 'inquiry', 'ipso', 'prior', 'ordo', 'cognoscendi', 'extension', 'deriving', 'unified', 'subsume', 'conclusions', 'appear', 'impasse', 'Seconded', 'Excellent', 'Touche', 'stipulate', '80', '%', 'difficulties', 'caused', 'Sixty-five', 'cast', 'oddly', 'titillating', 'cats', 'epitome', 'indifference', 'observation', 'standpoint', 'psychological', 'state', 'actual', 'pheromone-based', 'stink', 'desperation', 'places', 'taverns', 'tavern', 'Juice', 'Cornucopia', 'Certainly', 'misunderstanding', 'occurred', 'screwed', 'satisfied', 'Precisely', 'cultural', 'construct', 'adds', 'clarification', 'allows', 'boy-slash-friend-slash-girl-slash-friend', 'status', 'suffocating', 'hunger', 'stirring', 'newest', 'gain', 'acceptance', 'arbitrarily', 'siding', 'arrive', 'winding', 'seats', 'assuming', 'Girls', 'entail', 'synchronized', 'unusually', 'firm', 'cervix', 'titled', 'graduate', 'fungus', 'grows', 'improperly', 'sterilized', 'implements', 'bond', 'BFF', 'makeovers', 'initiate', 'phony', 'spirited', 'fights', 'frilly', 'nighties', 'disappointing', 'tonsils', 'shared', 'Vietnamese', 'Pillow', 'grasp', 'familiarizing', 'fairly', 'straightforward', 'heat', 'prion', 'circumference', 'areolas', 'Absolon', 'hath', 'kist', 'hir', 'Nicholas', 'scalded', 'towte', 'tale', 'doon', 'al', 'rowte', 'dared', 'Miller', 'Tale', 'dirtiest', 'hidden', 'drawers', '14th', 'worn', 'socks', 'Hint', 'ought', 'claim', 'pair-bonded', 'inordinate', 'ex', 'post', 'option', 'terminate', 'react', 'unavailable', 'realized', 'scored', 'Clearly', 'guests', 'harmless', 'lesbianism', 'iconic', 'bending', 'flummoxed', 'satisfactory', 'flushed', 'clammy', 'addition', 'involuntarily', 'sudden-onset', 'Tourette', 'syndrome', 'foot-long', 'Quiznos', 'examination', 'donate', 'slice', 'Canadian', 'experienced', 'distressing', 'vital', 'signs', 'Elevated', 'localized', 'vascular', 'throbbing', 'Ears', 'carbonated', 'Ask', 'alien', 'parasite', 'shows', 'Cortisol', 'menopause', 'aroused', 'logically', 'stomach', 'arousal', 'Religion', 'philosophies', 'fiction', 'concern', 'motivated', 'reject', 'suppressing', 'specimens', 'pursuit', 'pure', 'founded', 'logic', '130', 'raging', 'estrogen', 'gluteus', 'maximus', 'Shakespeare', 'metaphorical', 'beast', 'backs', 'blank', 'ape-like', 'adopt', 'Vulcan', 'Kolinar', 'Institute', 'Interdisciplinary', 'Studies', 'interactions', 'blog', 'all-expense-paid', 'spa', 'four-star', 'resort', 'Sur', 'establish', 'boundaries', 'valid', 'principle', 'upgraded', 'discussed', 'jeopardize', 'bunk', 'constipated', 'ideal', 'radioactive', 'lanthanoid', 'Remind', 'subscribe', 'Freudian', 'penis', 'envy', 'convenience', 'deny', 'comparison', 'plumbing', 'Word', 'though', 'prone', 'terrors', 'kicking', 'screaming', 'panic', 'stroke', 'penises', 'weigh', '120', 'miles', 'per', 'arrow', 'quiver', 'troubling', 'isolating', 'stored', 'destroying', 'laser', 'improving', 'socialization', 'thus', 'effectively', 'essence', 'teaching', 'perfo ...
# Hapax para Penny:
# ['unfamiliar', 'aversion', 'soiled', 'hosiery', 'concept', 'deity', 'baffled', 'attendance', 'Noted', 'Tepid', 'Neurobiologist', 'indicates…', 'Dandruff', 'scalp', 'flattered', 'factoid', 'silence', 'occasional', 'Foreman', 'Grill', 'seals', 'flavour', 'fat', 'Remarkable', 'Cultural', 'perceptions', 'subjective', 'slut', 'volunteering', 'electronically', 'centres', '128', 'rhinoceroses', 'domesticated', 'pets', 'wins', 'Second', 'Defend', 'Correct', 'Tuned', 'bayonets', 'postulate', 'alternate', 'differs', 'pose', 'giant', 'builds', 'dams', 'overlord', 'low-lying', 'city', 'Copenhagen', 'flooded', 'Thousands', 'Devastated', 'Danes', 'invent', 'namesake', 'pastry', 'kinder', 'suited', 'hiding', 'feminine', 'supplies', 'Subject', 'entropy', 'decay', 'eventual', 'establishment', 'efficiently', 'festival', 'humdrum', 'chitchat', 'master', 'degree', 'subtle', 'compared', 'real-world', 'outright', 'Babinski', 'Dirac', 'defecates', 'Clarke-Maxwell', 'mapping', 'neurological', 'substrates', 'subserve', 'global', 'processing', 'required', 'inquiry', 'ipso', 'prior', 'ordo', 'cognoscendi', 'extension', 'deriving', 'unified', 'subsume', 'conclusions', 'appear', 'impasse', 'Seconded', 'Excellent', 'Touche', 'stipulate', '80', '%', 'difficulties', 'caused', 'Sixty-five', 'cast', 'oddly', 'titillating', 'cats', 'epitome', 'indifference', 'observation', 'standpoint', 'psychological', 'state', 'actual', 'pheromone-based', 'stink', 'desperation', 'places', 'taverns', 'tavern', 'Juice', 'Cornucopia', 'Certainly', 'misunderstanding', 'occurred', 'screwed', 'satisfied', 'Precisely', 'cultural', 'construct', 'adds', 'clarification', 'allows', 'boy-slash-friend-slash-girl-slash-friend', 'status', 'suffocating', 'hunger', 'stirring', 'newest', 'gain', 'acceptance', 'arbitrarily', 'siding', 'arrive', 'winding', 'seats', 'assuming', 'Girls', 'entail', 'synchronized', 'unusually', 'firm', 'cervix', 'titled', 'graduate', 'fungus', 'grows', 'improperly', 'sterilized', 'implements', 'bond', 'BFF', 'makeovers', 'initiate', 'phony', 'spirited', 'fights', 'frilly', 'nighties', 'disappointing', 'tonsils', 'shared', 'Vietnamese', 'Pillow', 'grasp', 'familiarizing', 'fairly', 'straightforward', 'heat', 'prion', 'circumference', 'areolas', 'Absolon', 'hath', 'kist', 'hir', 'Nicholas', 'scalded', 'towte', 'tale', 'doon', 'al', 'rowte', 'dared', 'Miller', 'Tale', 'dirtiest', 'hidden', 'drawers', '14th', 'worn', 'socks', 'Hint', 'ought', 'claim', 'pair-bonded', 'inordinate', 'ex', 'post', 'option', 'terminate', 'react', 'unavailable', 'realized', 'scored', 'Clearly', 'guests', 'harmless', 'lesbianism', 'iconic', 'bending', 'flummoxed', 'satisfactory', 'flushed', 'clammy', 'addition', 'involuntarily', 'sudden-onset', 'Tourette', 'syndrome', 'foot-long', 'Quiznos', 'examination', 'donate', 'slice', 'Canadian', 'experienced', 'distressing', 'vital', 'signs', 'Elevated', 'localized', 'vascular', 'throbbing', 'Ears', 'carbonated', 'Ask', 'alien', 'parasite', 'shows', 'Cortisol', 'menopause', 'aroused', 'logically', 'stomach', 'arousal', 'Religion', 'philosophies', 'fiction', 'concern', 'motivated', 'reject', 'suppressing', 'specimens', 'pursuit', 'pure', 'founded', 'logic', '130', 'raging', 'estrogen', 'gluteus', 'maximus', 'Shakespeare', 'metaphorical', 'beast', 'backs', 'blank', 'ape-like', 'adopt', 'Vulcan', 'Kolinar', 'Institute', 'Interdisciplinary', 'Studies', 'interactions', 'blog', 'all-expense-paid', 'spa', 'four-star', 'resort', 'Sur', 'establish', 'boundaries', 'valid', 'principle', 'upgraded', 'discussed', 'jeopardize', 'bunk', 'constipated', 'ideal', 'radioactive', 'lanthanoid', 'Remind', 'subscribe', 'Freudian', 'penis', 'envy', 'convenience', 'deny', 'comparison', 'plumbing', 'Word', 'though', 'prone', 'terrors', 'kicking', 'screaming', 'panic', 'stroke', 'penises', 'weigh', '120', 'miles', 'per', 'arrow', 'quiver', 'troubling', 'isolating', 'stored', 'destroying', 'laser', 'improving', 'socialization', 'thus', 'effectively', 'essence', 'teaching', 'perfo ...
# Hapax para Howard:
# ['unfamiliar', 'aversion', 'soiled', 'hosiery', 'concept', 'deity', 'baffled', 'attendance', 'Noted', 'Tepid', 'Neurobiologist', 'indicates…', 'Dandruff', 'scalp', 'flattered', 'factoid', 'silence', 'occasional', 'Foreman', 'Grill', 'seals', 'flavour', 'fat', 'Remarkable', 'Cultural', 'perceptions', 'subjective', 'slut', 'volunteering', 'electronically', 'centres', '128', 'rhinoceroses', 'domesticated', 'pets', 'wins', 'Second', 'Defend', 'Correct', 'Tuned', 'bayonets', 'postulate', 'alternate', 'differs', 'pose', 'giant', 'builds', 'dams', 'overlord', 'low-lying', 'city', 'Copenhagen', 'flooded', 'Thousands', 'Devastated', 'Danes', 'invent', 'namesake', 'pastry', 'kinder', 'suited', 'hiding', 'feminine', 'supplies', 'Subject', 'entropy', 'decay', 'eventual', 'establishment', 'efficiently', 'festival', 'humdrum', 'chitchat', 'master', 'degree', 'subtle', 'compared', 'real-world', 'outright', 'Babinski', 'Dirac', 'defecates', 'Clarke-Maxwell', 'mapping', 'neurological', 'substrates', 'subserve', 'global', 'processing', 'required', 'inquiry', 'ipso', 'prior', 'ordo', 'cognoscendi', 'extension', 'deriving', 'unified', 'subsume', 'conclusions', 'appear', 'impasse', 'Seconded', 'Excellent', 'Touche', 'stipulate', '80', '%', 'difficulties', 'caused', 'Sixty-five', 'cast', 'oddly', 'titillating', 'cats', 'epitome', 'indifference', 'observation', 'standpoint', 'psychological', 'state', 'actual', 'pheromone-based', 'stink', 'desperation', 'places', 'taverns', 'tavern', 'Juice', 'Cornucopia', 'Certainly', 'misunderstanding', 'occurred', 'screwed', 'satisfied', 'Precisely', 'cultural', 'construct', 'adds', 'clarification', 'allows', 'boy-slash-friend-slash-girl-slash-friend', 'status', 'suffocating', 'hunger', 'stirring', 'newest', 'gain', 'acceptance', 'arbitrarily', 'siding', 'arrive', 'winding', 'seats', 'assuming', 'Girls', 'entail', 'synchronized', 'unusually', 'firm', 'cervix', 'titled', 'graduate', 'fungus', 'grows', 'improperly', 'sterilized', 'implements', 'bond', 'BFF', 'makeovers', 'initiate', 'phony', 'spirited', 'fights', 'frilly', 'nighties', 'disappointing', 'tonsils', 'shared', 'Vietnamese', 'Pillow', 'grasp', 'familiarizing', 'fairly', 'straightforward', 'heat', 'prion', 'circumference', 'areolas', 'Absolon', 'hath', 'kist', 'hir', 'Nicholas', 'scalded', 'towte', 'tale', 'doon', 'al', 'rowte', 'dared', 'Miller', 'Tale', 'dirtiest', 'hidden', 'drawers', '14th', 'worn', 'socks', 'Hint', 'ought', 'claim', 'pair-bonded', 'inordinate', 'ex', 'post', 'option', 'terminate', 'react', 'unavailable', 'realized', 'scored', 'Clearly', 'guests', 'harmless', 'lesbianism', 'iconic', 'bending', 'flummoxed', 'satisfactory', 'flushed', 'clammy', 'addition', 'involuntarily', 'sudden-onset', 'Tourette', 'syndrome', 'foot-long', 'Quiznos', 'examination', 'donate', 'slice', 'Canadian', 'experienced', 'distressing', 'vital', 'signs', 'Elevated', 'localized', 'vascular', 'throbbing', 'Ears', 'carbonated', 'Ask', 'alien', 'parasite', 'shows', 'Cortisol', 'menopause', 'aroused', 'logically', 'stomach', 'arousal', 'Religion', 'philosophies', 'fiction', 'concern', 'motivated', 'reject', 'suppressing', 'specimens', 'pursuit', 'pure', 'founded', 'logic', '130', 'raging', 'estrogen', 'gluteus', 'maximus', 'Shakespeare', 'metaphorical', 'beast', 'backs', 'blank', 'ape-like', 'adopt', 'Vulcan', 'Kolinar', 'Institute', 'Interdisciplinary', 'Studies', 'interactions', 'blog', 'all-expense-paid', 'spa', 'four-star', 'resort', 'Sur', 'establish', 'boundaries', 'valid', 'principle', 'upgraded', 'discussed', 'jeopardize', 'bunk', 'constipated', 'ideal', 'radioactive', 'lanthanoid', 'Remind', 'subscribe', 'Freudian', 'penis', 'envy', 'convenience', 'deny', 'comparison', 'plumbing', 'Word', 'though', 'prone', 'terrors', 'kicking', 'screaming', 'panic', 'stroke', 'penises', 'weigh', '120', 'miles', 'per', 'arrow', 'quiver', 'troubling', 'isolating', 'stored', 'destroying', 'laser', 'improving', 'socialization', 'thus', 'effectively', 'essence', 'teaching', 'perfo ...
# Hapax para Raj:
# ['unfamiliar', 'aversion', 'soiled', 'hosiery', 'concept', 'deity', 'baffled', 'attendance', 'Noted', 'Tepid', 'Neurobiologist', 'indicates…', 'Dandruff', 'scalp', 'flattered', 'factoid', 'silence', 'occasional', 'Foreman', 'Grill', 'seals', 'flavour', 'fat', 'Remarkable', 'Cultural', 'perceptions', 'subjective', 'slut', 'volunteering', 'electronically', 'centres', '128', 'rhinoceroses', 'domesticated', 'pets', 'wins', 'Second', 'Defend', 'Correct', 'Tuned', 'bayonets', 'postulate', 'alternate', 'differs', 'pose', 'giant', 'builds', 'dams', 'overlord', 'low-lying', 'city', 'Copenhagen', 'flooded', 'Thousands', 'Devastated', 'Danes', 'invent', 'namesake', 'pastry', 'kinder', 'suited', 'hiding', 'feminine', 'supplies', 'Subject', 'entropy', 'decay', 'eventual', 'establishment', 'efficiently', 'festival', 'humdrum', 'chitchat', 'master', 'degree', 'subtle', 'compared', 'real-world', 'outright', 'Babinski', 'Dirac', 'defecates', 'Clarke-Maxwell', 'mapping', 'neurological', 'substrates', 'subserve', 'global', 'processing', 'required', 'inquiry', 'ipso', 'prior', 'ordo', 'cognoscendi', 'extension', 'deriving', 'unified', 'subsume', 'conclusions', 'appear', 'impasse', 'Seconded', 'Excellent', 'Touche', 'stipulate', '80', '%', 'difficulties', 'caused', 'Sixty-five', 'cast', 'oddly', 'titillating', 'cats', 'epitome', 'indifference', 'observation', 'standpoint', 'psychological', 'state', 'actual', 'pheromone-based', 'stink', 'desperation', 'places', 'taverns', 'tavern', 'Juice', 'Cornucopia', 'Certainly', 'misunderstanding', 'occurred', 'screwed', 'satisfied', 'Precisely', 'cultural', 'construct', 'adds', 'clarification', 'allows', 'boy-slash-friend-slash-girl-slash-friend', 'status', 'suffocating', 'hunger', 'stirring', 'newest', 'gain', 'acceptance', 'arbitrarily', 'siding', 'arrive', 'winding', 'seats', 'assuming', 'Girls', 'entail', 'synchronized', 'unusually', 'firm', 'cervix', 'titled', 'graduate', 'fungus', 'grows', 'improperly', 'sterilized', 'implements', 'bond', 'BFF', 'makeovers', 'initiate', 'phony', 'spirited', 'fights', 'frilly', 'nighties', 'disappointing', 'tonsils', 'shared', 'Vietnamese', 'Pillow', 'grasp', 'familiarizing', 'fairly', 'straightforward', 'heat', 'prion', 'circumference', 'areolas', 'Absolon', 'hath', 'kist', 'hir', 'Nicholas', 'scalded', 'towte', 'tale', 'doon', 'al', 'rowte', 'dared', 'Miller', 'Tale', 'dirtiest', 'hidden', 'drawers', '14th', 'worn', 'socks', 'Hint', 'ought', 'claim', 'pair-bonded', 'inordinate', 'ex', 'post', 'option', 'terminate', 'react', 'unavailable', 'realized', 'scored', 'Clearly', 'guests', 'harmless', 'lesbianism', 'iconic', 'bending', 'flummoxed', 'satisfactory', 'flushed', 'clammy', 'addition', 'involuntarily', 'sudden-onset', 'Tourette', 'syndrome', 'foot-long', 'Quiznos', 'examination', 'donate', 'slice', 'Canadian', 'experienced', 'distressing', 'vital', 'signs', 'Elevated', 'localized', 'vascular', 'throbbing', 'Ears', 'carbonated', 'Ask', 'alien', 'parasite', 'shows', 'Cortisol', 'menopause', 'aroused', 'logically', 'stomach', 'arousal', 'Religion', 'philosophies', 'fiction', 'concern', 'motivated', 'reject', 'suppressing', 'specimens', 'pursuit', 'pure', 'founded', 'logic', '130', 'raging', 'estrogen', 'gluteus', 'maximus', 'Shakespeare', 'metaphorical', 'beast', 'backs', 'blank', 'ape-like', 'adopt', 'Vulcan', 'Kolinar', 'Institute', 'Interdisciplinary', 'Studies', 'interactions', 'blog', 'all-expense-paid', 'spa', 'four-star', 'resort', 'Sur', 'establish', 'boundaries', 'valid', 'principle', 'upgraded', 'discussed', 'jeopardize', 'bunk', 'constipated', 'ideal', 'radioactive', 'lanthanoid', 'Remind', 'subscribe', 'Freudian', 'penis', 'envy', 'convenience', 'deny', 'comparison', 'plumbing', 'Word', 'though', 'prone', 'terrors', 'kicking', 'screaming', 'panic', 'stroke', 'penises', 'weigh', '120', 'miles', 'per', 'arrow', 'quiver', 'troubling', 'isolating', 'stored', 'destroying', 'laser', 'improving', 'socialization', 'thus', 'effectively', 'essence', 'teaching', 'perfo ...
# Hapax para Amy:
# ['unfamiliar', 'aversion', 'soiled', 'hosiery', 'concept', 'deity', 'baffled', 'attendance', 'Noted', 'Tepid', 'Neurobiologist', 'indicates…', 'Dandruff', 'scalp', 'flattered', 'factoid', 'silence', 'occasional', 'Foreman', 'Grill', 'seals', 'flavour', 'fat', 'Remarkable', 'Cultural', 'perceptions', 'subjective', 'slut', 'volunteering', 'electronically', 'centres', '128', 'rhinoceroses', 'domesticated', 'pets', 'wins', 'Second', 'Defend', 'Correct', 'Tuned', 'bayonets', 'postulate', 'alternate', 'differs', 'pose', 'giant', 'builds', 'dams', 'overlord', 'low-lying', 'city', 'Copenhagen', 'flooded', 'Thousands', 'Devastated', 'Danes', 'invent', 'namesake', 'pastry', 'kinder', 'suited', 'hiding', 'feminine', 'supplies', 'Subject', 'entropy', 'decay', 'eventual', 'establishment', 'efficiently', 'festival', 'humdrum', 'chitchat', 'master', 'degree', 'subtle', 'compared', 'real-world', 'outright', 'Babinski', 'Dirac', 'defecates', 'Clarke-Maxwell', 'mapping', 'neurological', 'substrates', 'subserve', 'global', 'processing', 'required', 'inquiry', 'ipso', 'prior', 'ordo', 'cognoscendi', 'extension', 'deriving', 'unified', 'subsume', 'conclusions', 'appear', 'impasse', 'Seconded', 'Excellent', 'Touche', 'stipulate', '80', '%', 'difficulties', 'caused', 'Sixty-five', 'cast', 'oddly', 'titillating', 'cats', 'epitome', 'indifference', 'observation', 'standpoint', 'psychological', 'state', 'actual', 'pheromone-based', 'stink', 'desperation', 'places', 'taverns', 'tavern', 'Juice', 'Cornucopia', 'Certainly', 'misunderstanding', 'occurred', 'screwed', 'satisfied', 'Precisely', 'cultural', 'construct', 'adds', 'clarification', 'allows', 'boy-slash-friend-slash-girl-slash-friend', 'status', 'suffocating', 'hunger', 'stirring', 'newest', 'gain', 'acceptance', 'arbitrarily', 'siding', 'arrive', 'winding', 'seats', 'assuming', 'Girls', 'entail', 'synchronized', 'unusually', 'firm', 'cervix', 'titled', 'graduate', 'fungus', 'grows', 'improperly', 'sterilized', 'implements', 'bond', 'BFF', 'makeovers', 'initiate', 'phony', 'spirited', 'fights', 'frilly', 'nighties', 'disappointing', 'tonsils', 'shared', 'Vietnamese', 'Pillow', 'grasp', 'familiarizing', 'fairly', 'straightforward', 'heat', 'prion', 'circumference', 'areolas', 'Absolon', 'hath', 'kist', 'hir', 'Nicholas', 'scalded', 'towte', 'tale', 'doon', 'al', 'rowte', 'dared', 'Miller', 'Tale', 'dirtiest', 'hidden', 'drawers', '14th', 'worn', 'socks', 'Hint', 'ought', 'claim', 'pair-bonded', 'inordinate', 'ex', 'post', 'option', 'terminate', 'react', 'unavailable', 'realized', 'scored', 'Clearly', 'guests', 'harmless', 'lesbianism', 'iconic', 'bending', 'flummoxed', 'satisfactory', 'flushed', 'clammy', 'addition', 'involuntarily', 'sudden-onset', 'Tourette', 'syndrome', 'foot-long', 'Quiznos', 'examination', 'donate', 'slice', 'Canadian', 'experienced', 'distressing', 'vital', 'signs', 'Elevated', 'localized', 'vascular', 'throbbing', 'Ears', 'carbonated', 'Ask', 'alien', 'parasite', 'shows', 'Cortisol', 'menopause', 'aroused', 'logically', 'stomach', 'arousal', 'Religion', 'philosophies', 'fiction', 'concern', 'motivated', 'reject', 'suppressing', 'specimens', 'pursuit', 'pure', 'founded', 'logic', '130', 'raging', 'estrogen', 'gluteus', 'maximus', 'Shakespeare', 'metaphorical', 'beast', 'backs', 'blank', 'ape-like', 'adopt', 'Vulcan', 'Kolinar', 'Institute', 'Interdisciplinary', 'Studies', 'interactions', 'blog', 'all-expense-paid', 'spa', 'four-star', 'resort', 'Sur', 'establish', 'boundaries', 'valid', 'principle', 'upgraded', 'discussed', 'jeopardize', 'bunk', 'constipated', 'ideal', 'radioactive', 'lanthanoid', 'Remind', 'subscribe', 'Freudian', 'penis', 'envy', 'convenience', 'deny', 'comparison', 'plumbing', 'Word', 'though', 'prone', 'terrors', 'kicking', 'screaming', 'panic', 'stroke', 'penises', 'weigh', '120', 'miles', 'per', 'arrow', 'quiver', 'troubling', 'isolating', 'stored', 'destroying', 'laser', 'improving', 'socialization', 'thus', 'effectively', 'essence', 'teaching', 'perfo ...

# %% [markdown]
# ### 10. Gráfica de las 20 palabras más utilizadas

# %%
#Buscamos las 20 palabras más comunes
palabras_mas_comunes = frecuencia_palabras.most_common(20)

# Separamos las palabras y sus frecuencias en listas separadas
palabras, frecuencias = zip(*palabras_mas_comunes)

# Crear la gráfica de barras
plt.figure(figsize=(12, 6))
plt.bar(palabras, frecuencias)
plt.title("Las 20 palabras más utilizadas")
plt.xticks(rotation=45, fontsize=10)
plt.tight_layout()
plt.show()
